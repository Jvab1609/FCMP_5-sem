# %%
import sys
import platform
print("Python:", sys.version)
print("Platform:", platform.platform())

import tensorflow as tf
print("TensorFlow:", tf.__version__)

import numpy as np
print("NumPy:", np.__version__)

import torch
print("PyTorch:", torch.__version__)

from deepface import DeepFace
print("DeepFace importado com sucesso")
# Out:
# Python: 3.8.1 (tags/v3.8.1:1b293b6, Dec 18 2019, 23:11:46) [MSC v.1916 64 bit (AMD64)]
# Platform: Windows-10-10.0.22621-SP0
# TensorFlow: 2.13.0
# NumPy: 1.24.3
# PyTorch: 2.4.1+cpu
# DeepFace importado com sucesso

# %%
import pathlib
import sys
import torch

# Corrigir paths no Windows
if sys.platform == "win32":
    pathlib.PosixPath = pathlib.WindowsPath

# Carregar modelo do YOLOv5
model = torch.hub.load('ultralytics/yolov5', 'custom', path='modelo-800img-50epochs.pt', source='github')
print("Modelo YOLOv5 carregado com sucesso")
# Out:
# Using cache found in C:\Users\jvalb/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2025-5-21 Python-3.8.1 torch-2.4.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# Modelo YOLOv5 carregado com sucesso

# %%
import cv2
import sys
import os
import torch
from deepface import DeepFace

# Carregar modelo YOLOv5 personalizado
#model = torch.hub.load('ultralytics/yolov5', 'custom', path='modelo-800img-50epochs.pt', source='github', force_reload=True)

# Classe genérica se YOLO estiver treinado para múltiplos rótulos
class_names = {
    0: 'Pessoa',
    1: 'Joao',
    2: 'Gabriel'
}

# Abertura da webcam
cap = cv2.VideoCapture(1)
if not cap.isOpened():
    print("Erro ao abrir a webcam")
    sys.exit()

frame_count = 0
emotion_cache = {}
face_cache = {}

print("Pressione 'q' para sair.")

while True:
    ret, frame = cap.read()
    if not ret:
        print("Erro ao capturar frame")
        break

    results = model(frame)
    detections = results.xyxy[0].tolist()

    for detection in detections:
        x1, y1, x2, y2, conf, cls = detection
        x1, y1, x2, y2 = map(int, (x1, y1, x2, y2))
        cls = int(cls)
        nome_detectado = class_names.get(cls, "Pessoa")

        # Recorta rosto detectado
        cropped_face = frame[y1:y2, x1:x2]

        # Cria imagem temporária para análise
        temp_path = "temp_face.jpg"
        cv2.imwrite(temp_path, cropped_face)

        # Reconhecimento facial (apenas a cada 15 frames ou novo rosto)
        if frame_count % 5 == 0 or cls not in face_cache:
            try:
                # Detecta baseado nos rostos da pasta faces_db
                df = DeepFace.find(img_path=temp_path, db_path="faces_db", enforce_detection=False)
                if len(df) > 0 and len(df[0]) > 0:
                    identity_path = df[0].iloc[0]['identity']
                    label_face = os.path.basename(identity_path).replace(".jpg", "").replace(".jpeg", "")
                else:
                    label_face = "Desconhecido"
                face_cache[cls] = label_face
            except Exception as e:
                face_cache[cls] = "Erro"

        label_face = face_cache.get(cls, "Desconhecido")

        # Análise de emoção — pode ser aplicada, mas aqui optamos por não utilizar
        # if frame_count % 15 == 0 or cls not in emotion_cache:
        #     try:
        #         analysis = DeepFace.analyze(
        #             img_path=cropped_face,
        #             actions=['emotion'],
        #             enforce_detection=False
        #         )[0]
        #         #emotion = analysis['dominant_emotion']
        #     except:
        #         emotion = "Desconhecido"
        #     emotion_cache[cls] = emotion

        # emotion = emotion_cache.get(cls, "Desconhecido")

        # Mostra rótulo com nome e emoção
        # final_label = f"{label_face} ({conf*100:.1f}%) - {emotion}"

        
        #final_label = f"{label_face} ({conf*100:.1f}%)"
        final_label = f"{label_face}"
        if final_label.lower().startswith("gabriel"):
            color = (3, 252, 177)
        elif final_label.lower().startswith("joao"):
            color = (98, 3, 252)
        else:
            color = (0, 0, 255)
        
        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
        cv2.putText(frame, final_label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

    cv2.imshow("Reconhecimento Facial + Emoção", frame)

    frame_count += 1

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Pressione 'q' para sair.
# 25-05-21 15:03:36 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:03:37 - find function duration 0.20769524574279785 seconds
# 25-05-21 15:03:37 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:03:37 - find function duration 0.20139479637145996 seconds
# 25-05-21 15:03:37 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:03:37 - find function duration 0.20095491409301758 seconds
# 25-05-21 15:03:47 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:03:47 - find function duration 0.19341135025024414 seconds
# 25-05-21 15:03:47 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:03:47 - find function duration 0.1953415870666504 seconds
# 25-05-21 15:03:48 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:03:48 - find function duration 0.19240927696228027 seconds
# 25-05-21 15:03:51 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:03:51 - find function duration 0.20220160484313965 seconds
# 25-05-21 15:03:52 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:03:52 - find function duration 0.2001667022705078 seconds
# 25-05-21 15:03:52 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:03:53 - find function duration 0.2021803855895996 seconds
# 25-05-21 15:03:54 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:03:54 - find function duration 0.19056010246276855 seconds
# 25-05-21 15:03:54 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:03:54 - find function duration 0.187239408493042 seconds
# 25-05-21 15:03:54 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:03:55 - find function duration 0.1921403408050537 seconds
# 25-05-21 15:03:55 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:03:55 - find function duration 0.18652772903442383 seconds
# 25-05-21 15:03:55 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:03:55 - find function duration 0.1870880126953125 seconds
# 25-05-21 15:03:56 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:03:57 - find function duration 0.19339990615844727 seconds
# 25-05-21 15:03:57 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:03:57 - find function duration 0.20810747146606445 seconds
# 25-05-21 15:03:58 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:03:58 - find function duration 0.18671035766601562 seconds
# 25-05-21 15:04:00 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:00 - find function duration 0.1902635097503662 seconds
# 25-05-21 15:04:00 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:01 - find function duration 0.18674564361572266 seconds
# 25-05-21 15:04:01 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:01 - find function duration 0.18384552001953125 seconds
# 25-05-21 15:04:01 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:01 - find function duration 0.18894028663635254 seconds
# 25-05-21 15:04:02 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:02 - find function duration 0.19010281562805176 seconds
# 25-05-21 15:04:02 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:02 - find function duration 0.1894834041595459 seconds
# 25-05-21 15:04:03 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:03 - find function duration 0.1836400032043457 seconds
# 25-05-21 15:04:03 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:03 - find function duration 0.1828145980834961 seconds
# 25-05-21 15:04:04 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:04 - find function duration 0.1869509220123291 seconds
# 25-05-21 15:04:04 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:04 - find function duration 0.18334746360778809 seconds
# 25-05-21 15:04:05 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:05 - find function duration 0.18439817428588867 seconds
# 25-05-21 15:04:06 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:06 - find function duration 0.1851186752319336 seconds
# 25-05-21 15:04:06 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:06 - find function duration 0.18251466751098633 seconds
# 25-05-21 15:04:06 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:07 - find function duration 0.18674159049987793 seconds
# 25-05-21 15:04:07 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:07 - find function duration 0.18855762481689453 seconds
# 25-05-21 15:04:08 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:08 - find function duration 0.18361115455627441 seconds
# 25-05-21 15:04:08 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:09 - find function duration 0.18532752990722656 seconds
# 25-05-21 15:04:09 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:09 - find function duration 0.18483948707580566 seconds
# 25-05-21 15:04:09 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:09 - find function duration 0.19052529335021973 seconds
# 25-05-21 15:04:10 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:10 - find function duration 0.18957972526550293 seconds
# 25-05-21 15:04:11 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:11 - find function duration 0.1842808723449707 seconds
# 25-05-21 15:04:11 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:11 - find function duration 0.18696045875549316 seconds
# 25-05-21 15:04:12 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:12 - find function duration 0.18474364280700684 seconds
# 25-05-21 15:04:12 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:13 - find function duration 0.1843245029449463 seconds
# 25-05-21 15:04:17 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:17 - find function duration 0.19166278839111328 seconds
# 25-05-21 15:04:17 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:17 - find function duration 0.18859386444091797 seconds
# 25-05-21 15:04:17 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:17 - find function duration 0.18419599533081055 seconds
# 25-05-21 15:04:18 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:19 - find function duration 0.18901538848876953 seconds
# 25-05-21 15:04:19 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:19 - find function duration 0.18880200386047363 seconds
# 25-05-21 15:04:20 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:20 - find function duration 0.18733930587768555 seconds
# 25-05-21 15:04:20 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:21 - find function duration 0.18640518188476562 seconds
# 25-05-21 15:04:21 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:21 - find function duration 0.1826310157775879 seconds
# 25-05-21 15:04:21 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:21 - find function duration 0.18529343605041504 seconds
# 25-05-21 15:04:21 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:22 - find function duration 0.1927192211151123 seconds
# 25-05-21 15:04:22 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:22 - find function duration 0.19136333465576172 seconds
# 25-05-21 15:04:23 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:23 - find function duration 0.18561124801635742 seconds
# 25-05-21 15:04:23 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:24 - find function duration 0.18157172203063965 seconds
# 25-05-21 15:04:24 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:24 - find function duration 0.18223023414611816 seconds
# 25-05-21 15:04:25 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:25 - find function duration 0.19219470024108887 seconds
# 25-05-21 15:04:25 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:26 - find function duration 0.18758296966552734 seconds
# 25-05-21 15:04:26 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:26 - find function duration 0.18679237365722656 seconds
# 25-05-21 15:04:27 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:27 - find function duration 0.19115924835205078 seconds
# 25-05-21 15:04:27 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:28 - find function duration 0.18334102630615234 seconds
# 25-05-21 15:04:28 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:28 - find function duration 0.19211578369140625 seconds
# 25-05-21 15:04:29 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:29 - find function duration 0.18573808670043945 seconds
# 25-05-21 15:04:32 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:32 - find function duration 0.18944239616394043 seconds
# 25-05-21 15:04:34 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:34 - find function duration 0.1868288516998291 seconds
# 25-05-21 15:04:35 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:35 - find function duration 0.18599939346313477 seconds
# 25-05-21 15:04:36 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:37 - find function duration 0.18583083152770996 seconds
# 25-05-21 15:04:38 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:39 - find function duration 0.1845383644104004 seconds
# 25-05-21 15:04:40 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:40 - find function duration 0.18805480003356934 seconds
# 25-05-21 15:04:40 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:40 - find function duration 0.1851649284362793 seconds
# 25-05-21 15:04:40 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:41 - find function duration 0.18384313583374023 seconds
# 25-05-21 15:04:42 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:42 - find function duration 0.18637776374816895 seconds
# 25-05-21 15:04:44 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:44 - find function duration 0.1952657699584961 seconds
# 25-05-21 15:04:46 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:46 - find function duration 0.1879897117614746 seconds
# 25-05-21 15:04:47 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:47 - find function duration 0.18572354316711426 seconds
# 25-05-21 15:04:48 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:48 - find function duration 0.18595480918884277 seconds
# 25-05-21 15:04:48 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:48 - find function duration 0.18880081176757812 seconds
# 25-05-21 15:04:49 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:49 - find function duration 0.18694114685058594 seconds
# 25-05-21 15:04:51 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:51 - find function duration 0.1878032684326172 seconds
# 25-05-21 15:04:51 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:51 - find function duration 0.18461060523986816 seconds
# 25-05-21 15:04:53 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:53 - find function duration 0.18903446197509766 seconds
# 25-05-21 15:04:55 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:55 - find function duration 0.185089111328125 seconds
# 25-05-21 15:04:56 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:56 - find function duration 0.18897795677185059 seconds
# 25-05-21 15:04:56 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:57 - find function duration 0.19690346717834473 seconds
# 25-05-21 15:04:57 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:57 - find function duration 0.18590044975280762 seconds
# 25-05-21 15:04:57 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:57 - find function duration 0.1875901222229004 seconds
# 25-05-21 15:04:58 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:58 - find function duration 0.18750619888305664 seconds
# 25-05-21 15:04:59 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:04:59 - find function duration 0.1898956298828125 seconds
# 25-05-21 15:05:01 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:05:01 - find function duration 0.19127988815307617 seconds
# 25-05-21 15:05:02 - Searching temp_face.jpg in 4 length datastore
# 25-05-21 15:05:02 - find function duration 0.18599247932434082 seconds
